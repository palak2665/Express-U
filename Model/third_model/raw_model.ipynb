# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

# %%
def mediapipe_detection(image,model):
  image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
  image.flags.writeable = False
  results = model.process(image)
  image.flags.writeable = True
  image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
  return image,results

# %%
def draw_landmarks(image,results):
  mp_drawing.draw_landmarks(image,results.face_landmarks,mp_holistic.FACEMESH_CONTOURS)
  mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_holistic.POSE_CONNECTIONS)
  mp_drawing.draw_landmarks(image,results.left_hand_landmarks,mp_holistic.HAND_CONNECTIONS)
  mp_drawing.draw_landmarks(image,results.right_hand_landmarks,mp_holistic.HAND_CONNECTIONS)

# %%
def draw_styled_landmarks(image,results):
  mp_drawing.draw_landmarks(image,results.face_landmarks,mp_holistic.FACEMESH_CONTOURS,
                            mp_drawing.DrawingSpec(color=(80,110,10),thickness=1,circle_radius=1),
                            mp_drawing.DrawingSpec(color=(80,256,121),thickness=1,circle_radius=1)
                            )

  mp_drawing.draw_landmarks(image,results.pose_landmarks,mp_holistic.POSE_CONNECTIONS,
                            mp_drawing.DrawingSpec(color=(80,22,10),thickness=2,circle_radius=4),
                            mp_drawing.DrawingSpec(color=(80,44,121),thickness=2,circle_radius=2)
                            )

  mp_drawing.draw_landmarks(image,results.left_hand_landmarks,mp_holistic.HAND_CONNECTIONS,
                            mp_drawing.DrawingSpec(color=(121,22,76),thickness=2,circle_radius=4),
                            mp_drawing.DrawingSpec(color=(121,44,250),thickness=2,circle_radius=2)
                            )

  mp_drawing.draw_landmarks(image,results.right_hand_landmarks,mp_holistic.HAND_CONNECTIONS,
                            mp_drawing.DrawingSpec(color=(245,117,66),thickness=2,circle_radius=4),
                            mp_drawing.DrawingSpec(color=(245,66,230),thickness=2,circle_radius=2)
                            )

# %%
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5,min_tracking_confidence=0.5) as holistic:
  while cap.isOpened():
    ret,frame  = cap.read()
    # frame = cv2.resize(frame,(800,600))

    image,results = mediapipe_detection(frame,holistic)

    draw_styled_landmarks(image,results)
    cv2.imshow('result',cv2.flip(image,1))

    if cv2.waitKey(10) & 0xFF == ord('q'):
      break
  cap.release()
  cv2.destroyAllWindows()

# %%
# plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))

# %%
def extract_keypoints(results):
  pose = np.array([[res.x,res.y,res.z,res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
  face = np.array([[res.x,res.y,res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
  lh = np.array([[res.x,res.y,res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(63)
  rh = np.array([[res.x,res.y,res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(63)
  return np.concatenate([pose,face,lh,rh])

# %%
# test_result = extract_keypoints(results)[-10:]

# %%
# np.save('test',test_result)

# %%
# np.load('test.npy')

# %%
DATA_PATH = 'D:\\Final Year Project\\Express-U\\data\\vid_dataset'

actions = np.array(['hello','thanks','iloveyou'])

no_of_sequences = 30

sequence_length = 30

# %% [markdown]
# Folder creation for training data

# %%
for action in actions:
  for sequence in range(no_of_sequences):
    try:
      os.makedirs(os.path.join(DATA_PATH,action,str(sequence)))
    except:
      pass

# %% [markdown]
# Collecting Data for training

# %%
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5,min_tracking_confidence=0.5) as holistic:

  for action in actions:
    for sequence in range(no_of_sequences):
      for frame_num in range(sequence_length):

        ret,frame  = cap.read()
        image,results = mediapipe_detection(frame,holistic)
        draw_styled_landmarks(image,results)

        if frame_num == 0:
          cv2.putText(image,'STARTING COLLECTION',(120,200),cv2.FONT_HERSHEY_SIMPLEX,
                      1,(0,255,0),1,cv2.LINE_AA)

          cv2.putText(image,f'collectiong frames for {action} Video Number {sequence}',(15,12),cv2.FONT_HERSHEY_SIMPLEX,
                      0.5,(0,0,255),1,cv2.LINE_AA)

          cv2.imshow('result',image)


          cv2.waitKey(2000)
        else:
          cv2.putText(image,f'collectiong frames for {action} Video Number {sequence}',(15,12),cv2.FONT_HERSHEY_SIMPLEX,
                      0.5,(0,0,255),1,cv2.LINE_AA)

          cv2.imshow('result',image)


        keypoints = extract_keypoints(results)
        npy_path = os.path.join(DATA_PATH,action,str(sequence),str(frame_num))
        np.save(npy_path,keypoints)


        if cv2.waitKey(10) & 0xFF == ord('q'):
          break

  cap.release()
  cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num,label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thanks': 1, 'iloveyou': 2}

# %%
sequences,labels = [],[]
for action in actions:
  for sequence in range(no_of_sequences):
    window = []
    for frame_num in range(sequence_length):
      res = np.load(os.path.join(DATA_PATH,action,str(sequence),f'{frame_num}.npy'))
      window.append(res)
    sequences.append(window)
    labels.append(label_map[action])

# %%
x = np.array(sequences)

# %%
x.shape
# Out:
# (90, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
y.shape
# Out:
# (90, 3)

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.05)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = 'D:\\Final Year Project\\Express-U\\data\\Logs'
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64,return_sequences=True,activation='relu',input_shape=(30,1662)))
model.add(LSTM(128,return_sequences=True,activation='relu'))
model.add(LSTM(64,return_sequences=False,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(actions.shape[0],activation='softmax'))

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['categorical_accuracy'])

# %%
import tensorflow as tf
callback = tf.keras.callbacks.EarlyStopping(monitor="val_loss",patience=4, restore_best_weights=True)

# %%
model.fit(X_train,y_train,epochs=2000,callbacks=[callback])
# Out:
# Epoch 1/2000
# 3/3 [==============================] - ETA: 0s - loss: 1.1103 - categorical_accuracy: 0.3176WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 11s 168ms/step - loss: 1.1103 - categorical_accuracy: 0.3176
# Epoch 2/2000
# 3/3 [==============================] - ETA: 0s - loss: 1.5732 - categorical_accuracy: 0.2941WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 94ms/step - loss: 1.5732 - categorical_accuracy: 0.2941
# Epoch 3/2000
# 3/3 [==============================] - ETA: 0s - loss: 8.6087 - categorical_accuracy: 0.3647 WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 119ms/step - loss: 8.6087 - categorical_accuracy: 0.3647
# Epoch 4/2000
# 3/3 [==============================] - ETA: 0s - loss: 9.6664 - categorical_accuracy: 0.3412 WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s
ARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 79ms/step - loss: 0.1401 - categorical_accuracy: 0.9529
# Epoch 127/2000
# 3/3 [==============================] - ETA: 0s - loss: 0.1231 - categorical_accuracy: 0.9647WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 80ms/step - loss: 0.1231 - categorical_accuracy: 0.9647
# Epoch 128/2000
# 3/3 [==============================] - ETA: 0s - loss: 0.0956 - categorical_accuracy: 0.9765WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0956 - categorical_accuracy: 0.9765
# Epoch 129/2000
# 3/3 [==============================] - ETA: 0s - loss: 0.0888 - categorical_accuracy: 0.9765WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0888 - categorical_accuracy: 0.9765
# Epoch 130/2000
# 3/3 [==============================] - ETA: 0s - loss: 0.0691 - categorical_accuracy: 0.9765WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0691 - categorical_accuracy: 0.9765
# Epoch 131/2000
# 3/3 [==============================] - ETA: 0s - loss: 0.0760 - categorical_accuracy: 0.9882WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0760 - categorical_accuracy: 0.9882
# Epoch 132/2000
# 3/3 [==============================] - ETA: 0s - loss: 0.0592 - categorical_accuracy: 0.9882WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0592 - categorical_accuracy: 0.9882
# Epoch 133/2000
# 3/3 [==============================] - ETA: 0s - loss: 0.0593 - categorical_accuracy: 0.9765WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0593 - categorical_accuracy: 0.9765
# Epoch 134/2000
# 3/3 [==============================] - ETA: 0s - loss: 0.0603 - categorical_accuracy: 0.9765WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 77ms/step - loss: 0.0603 - categorical_accuracy: 0.9765
# Epoch 135/2000
# 3/3 [==============================] - ETA: 0s - loss: 0.0440 - categorical_accuracy: 0.9765WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0440 - categorical_accuracy: 0.9765
# Epoch 136/2000
# 3/3 [==============================] - ETA: 0s - loss: 0.0773 - categorical_accuracy: 0.9529WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0773 - categorical_accuracy: 0.9529
# Epoch 137/2000
# 3/3 [==============================] - ETA: 0s - loss: 0.3433 - categorical_accuracy: 0.9059WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 89ms/step - loss: 0.3433 - categorical_accuracy: 0.9059
# Epoch 138/2000
# 3/3 [==============================] - ETA: 0s - loss: 0.2101 - categorical_accuracy: 0.9059WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 74ms/step - loss: 0.2101 - categorical_accuracy: 0.9059
# Epoch 139/2000
# 3/3 [==============================] - ETA: 0s - loss: 0.1734 - categorical_accuracy: 0.9059WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 76ms/step - loss: 0.1734 - categorical_accuracy: 0.9059
# Epoch 140/2000
# ...
# Epoch 202/2000
# 3/3 [==============================] - ETA: 0s - loss: 5.5545e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 71ms/step - loss: 5.5545e-05 - categorical_accuracy: 1.0000
# Epoch 203/2000
# 3/3 [==============================] - ETA: 0s - loss: 5.3039e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 73ms/step - loss: 5.3039e-05 - categorical_accuracy: 1.0000
# Epoch 204/2000
# 3/3 [==============================] - ETA: 0s - loss: 5.0713e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 74ms/step - loss: 5.0713e-05 - categorical_accuracy: 1.0000
# Epoch 205/2000
# 3/3 [==============================] - ETA: 0s - loss: 4.9529e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 71ms/step - loss: 4.9529e-05 - categorical_accuracy: 1.0000
# Epoch 206/2000
# 3/3 [==============================] - ETA: 0s - loss: 4.7151e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 82ms/step - loss: 4.7151e-05 - categorical_accuracy: 1.0000
# Epoch 207/2000
# 3/3 [==============================] - ETA: 0s - loss: 4.6085e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 93ms/step - loss: 4.6085e-05 - categorical_accuracy: 1.0000
# Epoch 208/2000
# 3/3 [==============================] - ETA: 0s - loss: 4.4550e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 94ms/step - loss: 4.4550e-05 - categorical_accuracy: 1.0000
# Epoch 209/2000
# 3/3 [==============================] - ETA: 0s - loss: 4.2915e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 97ms/step - loss: 4.2915e-05 - categorical_accuracy: 1.0000
# Epoch 210/2000
# 3/3 [==============================] - ETA: 0s - loss: 4.1788e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 93ms/step - loss: 4.1788e-05 - categorical_accuracy: 1.0000
# Epoch 211/2000
# 3/3 [==============================] - ETA: 0s - loss: 4.0551e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 87ms/step - loss: 4.0551e-05 - categorical_accuracy: 1.0000
# Epoch 212/2000
# 3/3 [==============================] - ETA: 0s - loss: 3.9333e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 84ms/step - loss: 3.9333e-05 - categorical_accuracy: 1.0000
# Epoch 213/2000
# 3/3 [==============================] - ETA: 0s - loss: 3.8352e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 88ms/step - loss: 3.8352e-05 - categorical_accuracy: 1.0000
# Epoch 214/2000
# 3/3 [==============================] - ETA: 0s - loss: 3.7347e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 97ms/step - loss: 3.7347e-05 - categorical_accuracy: 1.0000
# Epoch 215/2000
# 3/3 [==============================] - ETA: 0s - loss: 3.6395e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 101ms/step - loss: 3.6395e-05 - categorical_accuracy: 1.0000
# Epoch 216/2000
# 3/3 [==============================] - ETA: 0s - loss: 3.5437e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 92ms/step - loss: 3.5437e-05 - categorical_accuracy: 1.0000
# Epoch 217/2000
# 3/3 [==============================] - ETA: 0s - loss: 3.4490e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 81ms/step - loss: 3.4490e-05 - categorical_accuracy: 1.0000
# Epoch 218/2000
# 3/3 [==============================] - ETA: 0s - loss: 3.3779e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 94ms/step - loss: 3.3779e-05 - categorical_accuracy: 1.0000
# Epoch 219/2000
# 3/3 [==============================] - ETA: 0s - loss: 3.2877e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 100ms/step - loss: 3.2877e-05 - categorical_accuracy: 1.0000
# Epoch 220/2000
# 3/3 [==============================] - ETA: 0s - loss: 3.2127e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 81ms/step - loss: 3.2127e-05 - categorical_accuracy: 1.0000
# Epoch 221/2000
# 3/3 [==============================] - ETA: 0s - loss: 3.1300e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 93ms/step - loss: 3.1300e-05 - categorical_accuracy: 1.0000
# Epoch 222/2000
# 3/3 [==============================] - ETA: 0s - loss: 3.0588e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 90ms/step - loss: 3.0588e-05 - categorical_accuracy: 1.0000
# Epoch 223/2000
# 3/3 [==============================] - ETA: 0s - loss: 2.9829e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 92ms/step - loss: 2.9829e-05 - categorical_accuracy: 1.0000
# Epoch 224/2000
# 3/3 [==============================] - ETA: 0s - loss: 2.9117e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 84ms/step - loss: 2.9117e-05 - categorical_accuracy: 1.0000
# Epoch 225/2000
# 3/3 [==============================] - ETA: 0s - loss: 2.8481e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 86ms/step - loss: 2.8481e-05 - categorical_accuracy: 1.0000
# Epoch 226/2000
# 3/3 [==============================] - ETA: 0s - loss: 2.7864e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 77ms/step - loss: 2.7864e-05 - categorical_accuracy: 1.0000
# Epoch 227/2000
# 3/3 [==============================] - ETA: 0s - loss: 2.7210e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 76ms/step - loss: 2.7210e-05 - categorical_accuracy: 1.0000
# Epoch 228/2000
# 3/3 [==============================] - ETA: 0s - loss: 2.6606e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 87ms/step - loss: 2.6606e-05 - categorical_accuracy: 1.0000
# Epoch 229/2000
# 3/3 [==============================] - ETA: 0s - loss: 2.5951e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 89ms/step - loss: 2.5951e-05 - categorical_accuracy: 1.0000
# Epoch 230/2000
# 3/3 [==============================] - ETA: 0s - loss: 2.5521e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 86ms/step - loss: 2.5521e-05 - categorical_accuracy: 1.0000
# Epoch 231/2000
# 3/3 [==============================] - ETA: 0s - loss: 2.4859e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 92ms/step - loss: 2.4859e-05 - categorical_accuracy: 1.0000
# Epoch 232/2000
# 3/3 [==============================] - ETA: 0s - loss: 2.4353e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 96ms/step - loss: 2.4353e-05 - categorical_accuracy: 1.0000
# Epoch 233/2000
# 3/3 [==============================] - ETA: 0s - loss: 2.3802e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 92ms/step - loss: 2.3802e-05 - categorical_accuracy: 1.0000
# Epoch 234/2000
# 3/3 [==============================] - ETA: 0s - loss: 2.3251e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 88ms/step - loss: 2.3251e-05 - categorical_accuracy: 1.0000
# Epoch 235/2000
# 3/3 [==============================] - ETA: 0s - loss: 2.2764e-05 - categorical_accuracy: 1.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 3/3 [==============================] - 0s 99ms/step - loss: 2.2764e-05 - categorical_accuracy: 1.0000
# Epoch 236/2000
# 1/3 [=========>....................] - ETA: 0s - loss: 2.6672e-05 - categorical_accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-65c7057e5081> in <module>
# ----> 1 model.fit(X_train,y_train,epochs=2000,callbacks=[callback])
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import multilabel_confusion_matrix,accuracy_score

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test,axis=1).tolist()
yhat = np.argmax(yhat,axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue,yhat)
# Out:
# array([[[2, 2],
#         [0, 1]],
#
#        [[3, 0],
#         [0, 2]],
#
#        [[3, 0],
#         [2, 0]]], dtype=int64)

# %%
accuracy_score(ytrue,yhat)
# Out:
# 0.6

# %%
model.save('actions.h5')
